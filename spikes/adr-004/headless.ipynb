# %%
import spike
spike.ensure_bundle()
for runner in (spike.run_quickjs, spike.run_mini_racer):
    result = runner()
    assert spike.check(result) == [], result
    print(result['runtime'], 'ok under nbconvert:', result['accepted'], result['serialised'])
